# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("match_multi_scale_ssim_test.csv")
array=df.to_numpy()

# %%
testing_array = array[:,2]
labels = array [0:40,1]
labels = labels.astype(int)
labels=list(labels)
print(type(labels))
print(testing_array)
print(type(testing_array))
# Out:
# <class 'list'>
# [1.         0.93911135 0.9428723  ... 0.9208646  0.93102014 1.        ]
# <class 'numpy.ndarray'>

# %%
testing_array = np.reshape(testing_array,(40, 40))

# %%
# def reduce_tick_freq(li,factor):
#     fin=[]
#     for _ in range(0,len(li),factor):
#         fin.append(li[_])
#         fin.append('')
#     return fin[:len(li)]

def reduce_tick_freq(li,factor):
    fin=[]
    for _ in range(0,len(li),factor):
        fin.append(li[_])
        for i in range(factor-1):
            fin.append('')
    return fin[:len(li)]

# %%
modified_x=reduce_tick_freq(labels,4)
modified_y=reduce_tick_freq(labels,4)

# %%
also_labels= labels
fig, ax = plt.subplots()
im = ax.imshow(testing_array)
cbar = fig.colorbar(im)


ax.set_xticks(np.arange(len(labels)))
ax.set_yticks(np.arange(len(also_labels)))

# ax.set_xticks(labels)
# ax.set_yticklabels(also_labels)

# ax.set_xticklabels(labels[::2], rotation=45)


ax.set_xticklabels(modified_x)
ax.set_yticklabels(modified_y)
# ax.set_xticklabels(labels)
# ax.set_yticklabels(also_labels)

# Rotate the tick labels and set their alignment.

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.

# for i in range(len(labels)):
#     for j in range(len(also_labels)):
#         text = ax.text(j, i, testing_array[i, j],
#                        ha="center", va="center", color="w")

# ax.set_title("This is just Priyank testing something.\n")
fig.tight_layout()
plt.show()
